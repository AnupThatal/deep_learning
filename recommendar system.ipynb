# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
movie_title=pd.read_csv('Movie-Recommender-in-python-master/Movie_Id_Titles')

# %%
movie_title
# Out:
#       item_id                                      title
# 0           1                           Toy Story (1995)
# 1           2                           GoldenEye (1995)
# 2           3                          Four Rooms (1995)
# 3           4                          Get Shorty (1995)
# 4           5                             Copycat (1995)
# ...       ...                                        ...
# 1677     1678                          Mat' i syn (1997)
# 1678     1679                           B. Monkey (1998)
# 1679     1680                       Sliding Doors (1998)
# 1680     1681                        You So Crazy (1994)
# 1681     1682  Scream of Stone (Schrei aus Stein) (1991)
#
# [1682 rows x 2 columns]

# %%
rating=pd.read_csv('Movie-Recommender-in-python-master/u.data',sep='\t',names=['userid','item_id','rating','timestamp'])

# %%
rating.head()
# Out:
#    userid  item_id  rating  timestamp
# 0       0       50       5  881250949
# 1       0      172       5  881250949
# 2       0      133       1  881250949
# 3     196      242       3  881250949
# 4     186      302       3  891717742

# %%
df=pd.merge(left=rating,right=movie_title,on="item_id")

# %%
new_df=pd.DataFrame(df.groupby(df['title'])['rating'].mean())

# %%
new_df['rating_count']=pd.DataFrame(df.groupby(df['title'])['rating'].count())

# %%
new_df.sort_values(ascending=False,by='rating_count')
# Out:
#                                       rating  rating_count
# title
# Star Wars (1977)                    4.359589           584
# Contact (1997)                      3.803536           509
# Fargo (1996)                        4.155512           508
# Return of the Jedi (1983)           4.007890           507
# Liar Liar (1997)                    3.156701           485
# ...                                      ...           ...
# Great Day in Harlem, A (1994)       5.000000             1
# Other Voices, Other Rooms (1997)    3.000000             1
# Good Morning (1971)                 1.000000             1
# Girls Town (1996)                   3.000000             1
# Á köldum klaka (Cold Fever) (1994)  3.000000             1
#
# [1664 rows x 2 columns]

# %%
new_df1=df.pivot_table(index='userid',columns='title',values='rating')

# %%
new_df1
# Out:
# title   'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# userid
# 0                             NaN           NaN                    NaN
# 1                             NaN           NaN                    2.0
# 2                             NaN           NaN                    NaN
# 3                             NaN           NaN                    NaN
# 4                             NaN           NaN                    NaN
# ...                           ...           ...                    ...
# 939                           NaN           NaN                    NaN
# 940                           NaN           NaN                    NaN
# 941                           NaN           NaN                    NaN
# 942                           NaN           NaN                    NaN
# 943                           NaN           NaN                    NaN
#
# title   12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# userid
# ...

# %%
star_wars_rating=new_df1['Star Wars (1977)']

# %%
similar_movie_star_wars=new_df1.corrwith(star_wars_rating)

# %%
similar_movie_star_wars=pd.DataFrame(similar_movie_star_wars)

# %%
similar_movie_star_wars
# Out:
#                                               0
# title
# 'Til There Was You (1997)              0.872872
# 1-900 (1994)                          -0.645497
# 101 Dalmatians (1996)                  0.211132
# 12 Angry Men (1957)                    0.184289
# 187 (1997)                             0.027398
# ...                                         ...
# Young Guns II (1990)                   0.228615
# Young Poisoner's Handbook, The (1995) -0.007374
# Zeus and Roxanne (1997)                0.818182
# unknown                                0.723123
# Á köldum klaka (Cold Fever) (1994)          NaN
#
# [1664 rows x 1 columns]

# %%
similar_movie_star_wars.reset_index(inplace=True)

# %%
similar_movie_star_wars.columns=['title','recommend']

# %%
similar_movie_star_wars.sort_values(by='recommend',ascending=False).head(10)
# Out:
#                                                   title  recommend
# 688                                  Hollow Reed (1996)        1.0
# 326                                 Commandments (1997)        1.0
# 343                                         Cosi (1996)        1.0
# 1072                                   No Escape (1994)        1.0
# 1418                                     Stripes (1981)        1.0
# 1398                                   Star Wars (1977)        1.0
# 935                              Man of the Year (1995)        1.0
# 137                   Beans of Egypt, Maine, The (1994)        1.0
# 1091  Old Lady Who Walked in the Sea, The (Vieille q...        1.0
# 1114                                 Outlaw, The (1943)        1.0

# %%
new_df2=pd.merge(left=star_war_df,right=new_df,on='title')

# %%
new_df.reset_index(inplace=True)

# %%
new_df
# Out:
#                                       title    rating  rating_count
# 0                 'Til There Was You (1997)  2.333333             9
# 1                              1-900 (1994)  2.600000             5
# 2                     101 Dalmatians (1996)  2.908257           109
# 3                       12 Angry Men (1957)  4.344000           125
# 4                                187 (1997)  3.024390            41
# ...                                     ...       ...           ...
# 1659                   Young Guns II (1990)  2.772727            44
# 1660  Young Poisoner's Handbook, The (1995)  3.341463            41
# 1661                Zeus and Roxanne (1997)  2.166667             6
# 1662                                unknown  3.444444             9
# 1663     Á köldum klaka (Cold Fever) (1994)  3.000000             1
#
# [1664 rows x 3 columns]

# %%
similar_movie_star_wars
# Out:
#                                       title  recommend
# 0                 'Til There Was You (1997)   0.872872
# 1                              1-900 (1994)  -0.645497
# 2                     101 Dalmatians (1996)   0.211132
# 3                       12 Angry Men (1957)   0.184289
# 4                                187 (1997)   0.027398
# ...                                     ...        ...
# 1659                   Young Guns II (1990)   0.228615
# 1660  Young Poisoner's Handbook, The (1995)  -0.007374
# 1661                Zeus and Roxanne (1997)   0.818182
# 1662                                unknown   0.723123
# 1663     Á köldum klaka (Cold Fever) (1994)        NaN
#
# [1664 rows x 2 columns]

# %%
Angry_men=new_df1['12 Angry Men (1957)']

# %%
Angry_men_similar=new_df1.corrwith(Angry_men)
# Out:
# /home/anup/anaconda3/lib/python3.8/site-packages/numpy/lib/function_base.py:2526: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# /home/anup/anaconda3/lib/python3.8/site-packages/numpy/lib/function_base.py:2455: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)

# %%
Angry_men_similar.reset_index()
# Out:
#                                       title         0
# 0                 'Til There Was You (1997) -0.500000
# 1                              1-900 (1994)       NaN
# 2                     101 Dalmatians (1996) -0.049890
# 3                       12 Angry Men (1957)  1.000000
# 4                                187 (1997)  0.666667
# ...                                     ...       ...
# 1659                   Young Guns II (1990) -0.361961
# 1660  Young Poisoner's Handbook, The (1995)  0.144338
# 1661                Zeus and Roxanne (1997)  1.000000
# 1662                                unknown  1.000000
# 1663     Á köldum klaka (Cold Fever) (1994)       NaN
#
# [1664 rows x 2 columns]

# %%
Angry_men_similar.sort_values(0,ascending=False).head(10)
# Out:
# title
# Spirits of the Dead (Tre passi nel delirio) (1968)    1.0
# Jefferson in Paris (1995)                             1.0
# Double Happiness (1994)                               1.0
# Nina Takes a Lover (1994)                             1.0
# Dream With the Fishes (1997)                          1.0
# Run of the Country, The (1995)                        1.0
# Screamers (1995)                                      1.0
# Pyromaniac's Love Story, A (1995)                     1.0
# FairyTale: A True Story (1997)                        1.0
# Stalker (1979)                                        1.0
# dtype: float64

# %%
star_war_df.drop('level_0',inplace=True,axis=1)

# %%
star_war_df.sort_values(0,ascending=False).head(10)
# Out:
#       index                                              title    0
# 688     688                                 Hollow Reed (1996)  1.0
# 326     326                                Commandments (1997)  1.0
# 343     343                                        Cosi (1996)  1.0
# 1072   1072                                   No Escape (1994)  1.0
# 1418   1418                                     Stripes (1981)  1.0
# 1398   1398                                   Star Wars (1977)  1.0
# 935     935                             Man of the Year (1995)  1.0
# 137     137                  Beans of Egypt, Maine, The (1994)  1.0
# 1091   1091  Old Lady Who Walked in the Sea, The (Vieille q...  1.0
# 1114   1114                                 Outlaw, The (1943)  1.0
